# %% [markdown]
# # Module: Debugging and Profiling

# %% [markdown]
# ## Using `pdb`

# %%
import pandas as pd

def do_something():
    df = pd.read_csv("https://s3.amazonaws.com/python-level-2/sales-funnel.csv")

    print(df.head())
    print(df[df['Status'] == 'pending'].count())
    
    df['Amount'] = df['Quantity'] * df['Price']
    print(df[df['Status'] == 'pending']['Amount'].sum())
    return df

# %% [markdown]
# ## Let's step through
# `import pdb; pdb.set_trace()`
#
# 1. l
# 2. ll
# 3. print values
# 4. step into (s)
# 5. step up from (u)
# 6. investigate, introspect
# 6. go to the next (n)
# 7. continue through

# %% [markdown]
# ## Exercise: Investigation
# 1. Find out what is tail
# 2. While in the pdb, find out what else you can do with `os.path`

# %%
import os


def get_path(filename):
    """Return file's path or empty string if no path."""
    head, tail = os.path.split(filename)
    return head

# %% [markdown]
# ## Exercise
# Fix the following to do a proper conversion from the base to the destination currency.
#
# We will be using [this Rates API](https://ratesapi.io/documentation/) for currency exchange rates.

# %%
def get_rate(base_currency, to_currency):
    res = requests.get('https://api.ratesapi.io/api/latest')
    return res[to_currency]

# %%
get_rate('EUR', 'GBP')

# %% [markdown]
# ## Lab
# Let's understand and [fix this code](https://raw.githubusercontent.com/AllenDowney/ThinkPython/master/code/Card.py)
#
# Drop `pdb`s throughout `card.py` to find out what is going on!

# %%
# %run -i 'card.py'

# %% [markdown]
# ### Exercise  A1
# What's the issue?
#
# ```python
# SyntaxError: invalid syntax
# ```

# %% [markdown]
# ### A brief review of lambdas

# %%
f = lambda val: val * 2

# %%
sorted(['hello', 'banana' 'apple', 'coffee', 'hi', 'yoo'], key=len)
# Out:
# ['hi', 'yoo', 'hello', 'coffee', 'bananaapple']

# %%
movies = [
    {"imdb": 7.2, "title": "The Little Rascals"},
    {"imdb": 8.5, "title": "The Usual Suspects"},
    {"imdb": 5.5, "title": "Pokemon The Movie"},
    {"imdb": 6.7, "title": "Guardians of the Galaxy 2"}
]

# %% [markdown]
# ### Exercise
# - Sort the movies by `imdb` score ascending
# - Sort by `imdb` score descending

# %% [markdown]
# ### Exercise A2
# - Drop a `pdb` before the next failing line and find out what is going on.
# - Why the `TypeError`?
# - HINT: What is `self.cards`?
# - HINT: Do a manual comprison of two of them
# - HINT: 2 different ways to fix this next bug, either Python 3 magic methods OR `key`

# %% [markdown]
# ### Exercise A3
# Find out what is going on here `find_defining_class`

# %% [markdown]
# ## Profiling Basics

# %%
import cProfile

# %%
# cProfile.run("2+2")

# %% [markdown]
# ### Exercise
# Profile the following code

# %%
def recip_square(i):
    return 1./i**2

def approx_pi(n=10000000):
    val = 0.
    for k in range(1,n+1):
        val += recip_square(k)
    return (6 * val)**.5

# %% [markdown]
# ### Exercise
# Optimize it. What can we do? Let's come up with ideas.

# %%
cProfile.run("do_something()")
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won
# Account     4
# Name        4
# Rep         4
# Manager     4
# Product     4
# Quantity    4
# Price       4
# Status      4
# dtype: int64
# 105000
#          18556 function calls (18282 primitive calls) in 0.223 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(append)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#        33    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#         1    0.000    0.000    0.223    0.223 <ipython-input-6-e5e177771649>:3(do_something)
#         1    0.000    0.000    0.223    0.223 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 __init__.py:111(_maybe_match_name)
#         1    0.000    0.000    0.000    0.000 __init__.py:307(_align_method_SERIES)
#         1    0.000    0.000    0.000    0.000 __init__.py:335(wrapper)
#         2    0.000    0.000    0.001    0.000 __init__.py:359(wrapper)
#         3    0.000    0.000    0.000    0.000 __init__.py:88(get_op_result_name)
#     47/42    0.000    0.000    0.000    0.000 _asarray.py:14(asarray)
#         6    0.000    0.000    0.000    0.000 _asarray.py:221(require)
#         6    0.000    0.000    0.000    0.000 _asarray.py:298(<setcomp>)
#        11    0.000    0.000    0.000    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#        48    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        48    0.000    0.000    0.000    0.000 _dtype.py:307(_name_includes_bit_suffix)
#        48    0.000    0.000    0.000    0.000 _dtype.py:321(_name_get)
#         9    0.000    0.000    0.000    0.000 _methods.py:37(_amax)
#         2    0.000    0.000    0.000    0.000 _methods.py:45(_sum)
#        22    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#         6    0.000    0.000    0.000    0.000 _policybase.py:281(_sanitize_header)
#        10    0.000    0.000    0.000    0.000 _policybase.py:293(header_source_parse)
#         6    0.000    0.000    0.000    0.000 _policybase.py:311(header_fetch_parse)
#        20    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        20    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#        82    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#         5    0.000    0.000    0.000    0.000 algorithms.py:1487(_get_take_nd_function)
#         5    0.000    0.000    0.000    0.000 algorithms.py:1616(take_nd)
#         1    0.000    0.000    0.000    0.000 array_ops.py:119(na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 array_ops.py:160(arithmetic_op)
#         2    0.000    0.000    0.000    0.000 array_ops.py:195(comparison_op)
#         2    0.000    0.000    0.000    0.000 array_ops.py:39(comp_method_OBJECT_ARRAY)
#         4    0.000    0.000    0.000    0.000 array_ops.py:404(maybe_upcast_datetimelike_array)
#         1    0.000    0.000    0.000    0.000 array_ops.py:429(maybe_upcast_for_op)
#         4    0.000    0.000    0.000    0.000 base.py:1032(__iter__)
#        12    0.000    0.000    0.000    0.000 base.py:1175(name)
#         2    0.000    0.000    0.000    0.000 base.py:1182(name)
#         6    0.000    0.000    0.000    0.000 base.py:1378(nlevels)
#         2    0.000    0.000    0.000    0.000 base.py:1646(is_unique)
#         5    0.000    0.000    0.000    0.000 base.py:1755(is_floating)
#         2    0.000    0.000    0.000    0.000 base.py:2000(inferred_type)
#         2    0.000    0.000    0.000    0.000 base.py:2007(is_all_dates)
#        20    0.000    0.000    0.000    0.000 base.py:201(construct_from_string)
#       245    0.000    0.000    0.001    0.000 base.py:256(is_dtype)
#         5    0.000    0.000    0.000    0.000 base.py:2851(get_loc)
#      11/5    0.000    0.000    0.002    0.000 base.py:293(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:3115(_validate_positional_slice)
#        25    0.000    0.000    0.000    0.000 base.py:3870(_values)
#         2    0.000    0.000    0.000    0.000 base.py:3896(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:3980(_coerce_scalar_to_index)
#        24    0.000    0.000    0.000    0.000 base.py:4036(__contains__)
#        52    0.000    0.000    0.000    0.000 base.py:4083(__getitem__)
#       199    0.000    0.000    0.001    0.000 base.py:413(find)
#         4    0.000    0.000    0.000    0.000 base.py:4196(equals)
#         4    0.000    0.000    0.000    0.000 base.py:424(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:4275(identical)
#         2    0.000    0.000    0.000    0.000 base.py:4288(<genexpr>)
#         7    0.000    0.000    0.000    0.000 base.py:463(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:492(_get_attributes_dict)
#         1    0.000    0.000    0.000    0.000 base.py:496(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 base.py:4976(_maybe_cast_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:4985(_validate_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:520(is_)
#         1    0.000    0.000    0.000    0.000 base.py:5235(insert)
#         9    0.000    0.000    0.000    0.000 base.py:544(_reset_identity)
#         2    0.000    0.000    0.000    0.000 base.py:554(_engine)
#        26    0.000    0.000    0.002    0.000 base.py:5557(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:561(<lambda>)
#        22    0.000    0.000    0.000    0.000 base.py:5654(maybe_extract_name)
#        64    0.000    0.000    0.000    0.000 base.py:567(__len__)
#         5    0.000    0.000    0.000    0.000 base.py:5670(_maybe_cast_with_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:5724(_maybe_cast_data_without_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:573(__array__)
#         5    0.000    0.000    0.000    0.000 base.py:590(dtype)
#         8    0.000    0.000    0.000    0.000 base.py:637(ndim)
#         2    0.000    0.000    0.000    0.000 base.py:701(take)
#         3    0.000    0.000    0.001    0.000 base.py:909(format)
#         2    0.000    0.000    0.001    0.000 base.py:931(_format_with_header)
#         2    0.000    0.000    0.000    0.000 base.py:942(<listcomp>)
#         2    0.000    0.000    0.000    0.000 blocks.py:111(_simple_new)
#         4    0.000    0.000    0.000    0.000 blocks.py:1238(take_nd)
#        33    0.000    0.000    0.000    0.000 blocks.py:124(__init__)
#        33    0.000    0.000    0.000    0.000 blocks.py:135(_check_ndim)
#        10    0.000    0.000    0.000    0.000 blocks.py:176(_consolidate_key)
#        19    0.000    0.000    0.000    0.000 blocks.py:201(internal_values)
#         6    0.000    0.000    0.000    0.000 blocks.py:207(array_values)
#         1    0.000    0.000    0.000    0.000 blocks.py:213(get_values)
#         4    0.000    0.000    0.000    0.000 blocks.py:229(fill_value)
#        64    0.000    0.000    0.000    0.000 blocks.py:233(mgr_locs)
#        33    0.000    0.000    0.000    0.000 blocks.py:237(mgr_locs)
#        11    0.000    0.000    0.000    0.000 blocks.py:2374(__init__)
#         4    0.000    0.000    0.000    0.000 blocks.py:244(make_block)
#        17    0.000    0.000    0.000    0.000 blocks.py:256(make_block_same_class)
#        24    0.000    0.000    0.001    0.000 blocks.py:2655(get_block_type)
#        16    0.000    0.000    0.001    0.000 blocks.py:2701(make_block)
#         8    0.000    0.000    0.000    0.000 blocks.py:2728(_extend_blocks)
#         2    0.000    0.000    0.000    0.000 blocks.py:287(_slice)
#         2    0.000    0.000    0.000    0.000 blocks.py:292(getitem_block)
#         5    0.000    0.000    0.000    0.000 blocks.py:311(shape)
#        46    0.000    0.000    0.000    0.000 blocks.py:315(dtype)
#        20    0.000    0.000    0.000    0.000 blocks.py:319(iget)
#         4    0.000    0.000    0.000    0.000 blocks.py:340(apply)
#         4    0.000    0.000    0.000    0.000 blocks.py:350(_split_op_result)
#         1    0.000    0.000    0.000    0.000 blocks.py:514(astype)
#         1    0.000    0.000    0.000    0.000 blocks.py:675(copy)
#        14    0.000    0.000    0.000    0.000 cast.py:1185(maybe_castable)
#        10    0.000    0.000    0.000    0.000 cast.py:1199(maybe_infer_to_datetimelike)
#        13    0.000    0.000    0.000    0.000 cast.py:1308(maybe_cast_to_datetime)
#         4    0.000    0.000    0.000    0.000 cast.py:1568(construct_1d_object_array_from_listlike)
#        11    0.000    0.000    0.000    0.000 cast.py:1593(construct_1d_ndarray_preserving_na)
#         4    0.000    0.000    0.000    0.000 cast.py:442(maybe_promote)
#         4    0.000    0.000    0.000    0.000 cast.py:598(_ensure_dtype_type)
#         1    0.000    0.000    0.105    0.105 client.py:1001(_send_output)
#         1    0.000    0.000    0.000    0.000 client.py:1055(putrequest)
#         1    0.000    0.000    0.000    0.000 client.py:1182(_encode_request)
#         1    0.000    0.000    0.000    0.000 client.py:1186(_validate_method)
#         1    0.000    0.000    0.000    0.000 client.py:1195(_validate_path)
#         1    0.000    0.000    0.000    0.000 client.py:1203(_validate_host)
#         4    0.000    0.000    0.000    0.000 client.py:1211(putheader)
#         1    0.000    0.000    0.105    0.105 client.py:1239(endheaders)
#         1    0.000    0.000    0.105    0.105 client.py:1252(request)
#         1    0.000    0.000    0.105    0.105 client.py:1257(_send_request)
#         4    0.000    0.000    0.000    0.000 client.py:1259(<genexpr>)
#         1    0.000    0.000    0.067    0.067 client.py:1303(getresponse)
#         1    0.000    0.000    0.017    0.017 client.py:1378(__init__)
#         1    0.000    0.000    0.104    0.104 client.py:1414(connect)
#         1    0.000    0.000    0.002    0.002 client.py:204(parse_headers)
#         1    0.000    0.000    0.001    0.001 client.py:237(__init__)
#         1    0.000    0.000    0.064    0.064 client.py:267(_read_status)
#         1    0.000    0.000    0.067    0.067 client.py:300(begin)
#         1    0.000    0.000    0.000    0.000 client.py:380(_check_close)
#         1    0.000    0.000    0.004    0.004 client.py:409(_close_conn)
#         1    0.000    0.000    0.000    0.000 client.py:414(close)
#         1    0.000    0.000    0.000    0.000 client.py:426(flush)
#         1    0.000    0.000    0.004    0.004 client.py:447(read)
#         1    0.000    0.000    0.000    0.000 client.py:605(_safe_read)
#         1    0.000    0.000    0.000    0.000 client.py:729(info)
#         1    0.000    0.000    0.000    0.000 client.py:787(_get_content_length)
#         1    0.000    0.000    0.000    0.000 client.py:819(__init__)
#         1    0.000    0.000    0.000    0.000 client.py:865(_get_hostport)
#         1    0.000    0.000    0.000    0.000 client.py:885(set_debuglevel)
#         1    0.000    0.000    0.047    0.047 client.py:919(connect)
#         1    0.000    0.000    0.000    0.000 client.py:928(close)
#         1    0.000    0.000    0.105    0.105 client.py:942(send)
#         5    0.000    0.000    0.000    0.000 client.py:980(_output)
#         7    0.000    0.000    0.000    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1064(is_numeric_v_string_like)
#         7    0.000    0.000    0.000    0.000 common.py:1180(needs_i8_conversion)
#        10    0.000    0.000    0.000    0.000 common.py:1223(is_numeric_dtype)
#        11    0.000    0.000    0.000    0.000 common.py:1265(is_string_like_dtype)
#        11    0.000    0.000    0.000    0.000 common.py:1293(<lambda>)
#        41    0.000    0.000    0.000    0.000 common.py:1296(is_float_dtype)
#         1    0.000    0.000    0.190    0.190 common.py:130(urlopen)
#        28    0.000    0.000    0.000    0.000 common.py:1330(is_bool_dtype)
#       196    0.000    0.000    0.001    0.000 common.py:1460(is_extension_array_dtype)
#        57    0.000    0.000    0.000    0.000 common.py:149(cast_scalar_indexer)
#         2    0.000    0.000    0.000    0.000 common.py:150(ensure_python_int)
#         9    0.000    0.000    0.000    0.000 common.py:1509(is_complex_dtype)
#         1    0.000    0.000    0.195    0.195 common.py:152(get_filepath_or_buffer)
#        23    0.000    0.000    0.000    0.000 common.py:1541(_is_dtype)
#        61    0.000    0.000    0.000    0.000 common.py:1565(_get_dtype)
#       211    0.000    0.000    0.000    0.000 common.py:1600(_is_dtype_type)
#        36    0.000    0.000    0.000    0.000 common.py:1733(pandas_dtype)
#       130    0.000    0.000    0.000    0.000 common.py:178(classes)
#       130    0.000    0.000    0.000    0.000 common.py:180(<lambda>)
#        81    0.000    0.000    0.000    0.000 common.py:183(classes_and_not_datetimelike)
#        81    0.000    0.000    0.000    0.000 common.py:188(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:190(all_none)
#         2    0.000    0.000    0.000    0.000 common.py:194(<genexpr>)
#        65    0.000    0.000    0.000    0.000 common.py:194(is_object_dtype)
#        11    0.000    0.000    0.000    0.000 common.py:218(asarray_tuplesafe)
#        24    0.000    0.000    0.000    0.000 common.py:224(is_sparse)
#         1    0.000    0.000    0.000    0.000 common.py:274(maybe_iterable_to_list)
#         8    0.000    0.000    0.000    0.000 common.py:283(is_null_slice)
#         1    0.000    0.000    0.000    0.000 common.py:302(infer_compression)
#        25    0.000    0.000    0.000    0.000 common.py:329(apply_if_callable)
#        15    0.000    0.000    0.000    0.000 common.py:348(is_datetime64_dtype)
#        47    0.000    0.000    0.000    0.000 common.py:381(is_datetime64tz_dtype)
#        38    0.000    0.000    0.000    0.000 common.py:422(is_timedelta64_dtype)
#        64    0.000    0.000    0.000    0.000 common.py:456(is_period_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:49(is_url)
#        57    0.000    0.000    0.000    0.000 common.py:492(is_interval_dtype)
#         3    0.000    0.000    0.001    0.000 common.py:50(new_method)
#        98    0.000    0.000    0.001    0.000 common.py:530(is_categorical_dtype)
#        12    0.000    0.000    0.000    0.000 common.py:566(is_string_dtype)
#        12    0.000    0.000    0.000    0.000 common.py:595(condition)
#        11    0.000    0.000    0.000    0.000 common.py:598(is_excluded_dtype)
#        44    0.000    0.000    0.000    0.000 common.py:603(<genexpr>)
#         5    0.000    0.000    0.000    0.000 common.py:608(is_dtype_equal)
#         3    0.000    0.000    0.000    0.000 common.py:67(_expand_user)
#        53    0.000    0.000    0.000    0.000 common.py:696(is_integer_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:750(is_signed_integer_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:806(is_unsigned_integer_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:88(validate_header_arg)
#        32    0.000    0.000    0.000    0.000 common.py:905(is_datetime64_any_dtype)
#        26    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#         3    0.000    0.000    0.000    0.000 common.py:97(stringify_path)
#        97    0.000    0.000    0.001    0.000 config.py:104(_get_option)
#         2    0.000    0.000    0.000    0.000 config.py:112(_set_option)
#         2    0.000    0.000    0.000    0.000 config.py:176(get_default_val)
#        96    0.000    0.000    0.001    0.000 config.py:232(__call__)
#         1    0.000    0.000    0.000    0.000 config.py:394(__init__)
#         1    0.000    0.000    0.000    0.000 config.py:402(__enter__)
#         1    0.000    0.000    0.000    0.000 config.py:403(<listcomp>)
#         1    0.000    0.000    0.000    0.000 config.py:408(__exit__)
#       101    0.000    0.000    0.000    0.000 config.py:539(_select_options)
#        99    0.000    0.000    0.000    0.000 config.py:557(_get_root)
#       197    0.000    0.000    0.000    0.000 config.py:571(_get_deprecated_option)
#         4    0.000    0.000    0.000    0.000 config.py:587(_get_registered_option)
#       101    0.000    0.000    0.000    0.000 config.py:598(_translate_key)
#        96    0.000    0.000    0.000    0.000 config.py:610(_warn_if_deprecated)
#         2    0.000    0.000    0.000    0.000 config.py:792(inner)
#       101    0.000    0.000    0.000    0.000 config.py:86(_get_single_key)
#         2    0.000    0.000    0.000    0.000 config_init.py:364(_deprecate_negative_int_max_colwidth)
#         1    0.000    0.000    0.000    0.000 console.py:53(in_interactive_session)
#         1    0.000    0.000    0.000    0.000 console.py:77(in_ipython_frontend)
#         1    0.000    0.000    0.000    0.000 console.py:8(get_console_size)
#         1    0.000    0.000    0.007    0.007 construction.py:237(init_dict)
#         1    0.000    0.000    0.001    0.001 construction.py:329(_homogenize)
#        34    0.000    0.000    0.000    0.000 construction.py:339(extract_array)
#        15    0.000    0.000    0.001    0.000 construction.py:390(sanitize_array)
#        15    0.000    0.000    0.001    0.000 construction.py:520(_try_cast)
#         9    0.000    0.000    0.000    0.000 construction.py:580(is_empty_data)
#         1    0.000    0.000    0.002    0.002 construction.py:60(arrays_to_mgr)
#         1    0.000    0.000    0.002    0.002 construction.py:600(create_series_with_explicit_dtype)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:117(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:238(helper)
#         1    0.000    0.000    0.000    0.000 contextlib.py:82(__init__)
#         3    0.000    0.000    0.000    0.000 dispatch.py:11(should_extension_dispatch)
#         2    0.000    0.000    0.000    0.000 dtype.py:187(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1062(construct_from_string)
#        50    0.000    0.000    0.000    0.000 dtypes.py:1116(is_dtype)
#         2    0.000    0.000    0.000    0.000 dtypes.py:281(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:694(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:853(construct_from_string)
#        57    0.000    0.000    0.000    0.000 dtypes.py:903(is_dtype)
#         6    0.000    0.000    0.000    0.000 enum.py:283(__call__)
#         6    0.000    0.000    0.000    0.000 enum.py:562(__new__)
#         1    0.000    0.000    0.000    0.000 expressions.py:186(_has_bool_dtype)
#         1    0.000    0.000    0.000    0.000 expressions.py:195(_bool_arith_check)
#         1    0.000    0.000    0.000    0.000 expressions.py:217(evaluate)
#         1    0.000    0.000    0.000    0.000 expressions.py:61(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 expressions.py:71(_can_use_numexpr)
#         1    0.000    0.000    0.000    0.000 expressions.py:97(_evaluate_numexpr)
#         1    0.000    0.000    0.000    0.000 feedparser.py:101(push)
#         2    0.000    0.000    0.000    0.000 feedparser.py:122(pushlines)
#         2    0.000    0.000    0.000    0.000 feedparser.py:125(__iter__)
#        13    0.000    0.000    0.000    0.000 feedparser.py:128(__next__)
#         1    0.000    0.000    0.000    0.000 feedparser.py:139(__init__)
#         1    0.000    0.000    0.001    0.001 feedparser.py:173(feed)
#         2    0.000    0.000    0.001    0.000 feedparser.py:178(_call_parse)
#         1    0.000    0.000    0.000    0.000 feedparser.py:184(close)
#         1    0.000    0.000    0.000    0.000 feedparser.py:197(_new_message)
#         1    0.000    0.000    0.000    0.000 feedparser.py:210(_pop_message)
#         2    0.000    0.000    0.001    0.000 feedparser.py:218(_parsegen)
#         1    0.000    0.000    0.000    0.000 feedparser.py:471(_parse_headers)
#         1    0.000    0.000    0.000    0.000 feedparser.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 feedparser.py:70(close)
#        13    0.000    0.000    0.000    0.000 feedparser.py:78(readline)
#         1    0.000    0.000    0.000    0.000 format.py:1026(<listcomp>)
#         2    0.000    0.000    0.000    0.000 format.py:1033(has_index_names)
#         1    0.000    0.000    0.000    0.000 format.py:1037(has_column_names)
#         2    0.000    0.000    0.000    0.000 format.py:1041(show_row_idx_names)
#         1    0.000    0.000    0.000    0.000 format.py:1045(show_col_idx_names)
#         1    0.000    0.000    0.000    0.000 format.py:1049(_get_formatted_index)
#         1    0.000    0.000    0.000    0.000 format.py:1052(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 format.py:1067(<listcomp>)
#         9    0.000    0.000    0.002    0.000 format.py:1103(format_array)
#         9    0.000    0.000    0.000    0.000 format.py:1183(__init__)
#         9    0.000    0.000    0.002    0.000 format.py:1209(get_result)
#         5    0.000    0.000    0.001    0.000 format.py:1213(_format_strings)
#        25    0.000    0.000    0.000    0.000 format.py:1232(_format)
#         4    0.000    0.000    0.000    0.000 format.py:1444(_format_strings)
#        23    0.000    0.000    0.000    0.000 format.py:1445(<lambda>)
#         4    0.000    0.000    0.000    0.000 format.py:1446(<listcomp>)
#        18    0.000    0.000    0.001    0.000 format.py:1723(_make_fixed_width)
#       111    0.000    0.000    0.000    0.000 format.py:1736(<genexpr>)
#        93    0.000    0.000    0.000    0.000 format.py:1745(just)
#        18    0.000    0.000    0.000    0.000 format.py:1751(<listcomp>)
#         3    0.000    0.000    0.000    0.000 format.py:1798(_has_names)
#         1    0.000    0.000    0.000    0.000 format.py:1914(_binify)
#         1    0.000    0.000    0.000    0.000 format.py:231(__init__)
#         1    0.000    0.000    0.000    0.000 format.py:263(_chk_truncate)
#         1    0.000    0.000    0.000    0.000 format.py:292(_get_footer)
#         1    0.000    0.000    0.000    0.000 format.py:331(_get_formatted_index)
#         1    0.000    0.000    0.000    0.000 format.py:342(_get_formatted_values)
#         1    0.000    0.000    0.000    0.000 format.py:350(to_string)
#        11    0.000    0.000    0.000    0.000 format.py:390(__init__)
#       356    0.000    0.000    0.000    0.000 format.py:393(len)
#        41    0.000    0.000    0.000    0.000 format.py:396(justify)
#         4    0.000    0.000    0.000    0.000 format.py:399(adjoin)
#        11    0.000    0.000    0.000    0.000 format.py:442(_get_adjustment)
#         1    0.000    0.000    0.000    0.000 format.py:457(should_show_dimensions)
#        17    0.000    0.000    0.000    0.000 format.py:463(_get_formatter)
#         2    0.000    0.000    0.000    0.000 format.py:475(get_buffer)
#         1    0.000    0.000    0.006    0.006 format.py:511(get_result)
#         1    0.000    0.000    0.000    0.000 format.py:541(__init__)
#         1    0.000    0.000    0.000    0.000 format.py:633(_chk_truncate)
#         1    0.000    0.000    0.005    0.005 format.py:726(_to_str_columns)
#         1    0.000    0.000    0.000    0.000 format.py:732(<dictcomp>)
#        16    0.000    0.000    0.000    0.000 format.py:768(<genexpr>)
#        48    0.000    0.000    0.000    0.000 format.py:775(<genexpr>)
#         1    0.000    0.000    0.006    0.006 format.py:817(write_result)
#         1    0.000    0.000    0.000    0.000 format.py:877(_join_multiline)
#         1    0.000    0.000    0.000    0.000 format.py:883(<listcomp>)
#         1    0.000    0.000    0.000    0.000 format.py:885(<listcomp>)
#         8    0.000    0.000    0.000    0.000 format.py:886(<listcomp>)
#         1    0.000    0.000    0.006    0.006 format.py:916(to_string)
#         8    0.000    0.000    0.003    0.000 format.py:951(_format_col)
#         1    0.000    0.000    0.001    0.001 format.py:992(_get_formatted_column_labels)
#         5    0.000    0.000    0.000    0.000 frame.py:1099(__len__)
#         8    0.000    0.000    0.000    0.000 frame.py:2816(_ixs)
#         8    0.000    0.000    0.000    0.000 frame.py:2854(_get_column_array)
#         9    0.000    0.000    0.000    0.000 frame.py:2861(_iter_column_arrays)
#         7    0.000    0.000    0.002    0.000 frame.py:2869(__getitem__)
#         2    0.000    0.000    0.002    0.001 frame.py:2926(_getitem_bool_array)
#         1    0.000    0.000    0.001    0.001 frame.py:3024(__setitem__)
#         1    0.000    0.000    0.001    0.001 frame.py:3105(_set_item)
#         1    0.000    0.000    0.000    0.000 frame.py:3158(_ensure_valid_index)
#        12    0.000    0.000    0.000    0.000 frame.py:3180(_box_col_values)
#         1    0.000    0.000    0.000    0.000 frame.py:3698(_sanitize_column)
#         1    0.000    0.000    0.000    0.000 frame.py:3718(reindexer)
#         6    0.000    0.000    0.000    0.000 frame.py:421(_constructor)
#         6    0.000    0.000    0.007    0.001 frame.py:441(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:4866(isna)
#         8    0.000    0.000    0.000    0.000 frame.py:568(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:585(shape)
#         1    0.000    0.000    0.000    0.000 frame.py:607(_is_homogeneous_type)
#         1    0.000    0.000    0.000    0.000 frame.py:717(_info_repr)
#         1    0.000    0.000    0.007    0.007 frame.py:726(__repr__)
#         1    0.000    0.000    0.007    0.007 frame.py:802(to_string)
#         1    0.000    0.000    0.002    0.002 frame.py:8379(count)
#         1    0.000    0.000    0.001    0.001 frame.py:8527(_reduce)
#         1    0.000    0.000    0.000    0.000 frame.py:8541(<listcomp>)
#         1    0.000    0.000    0.000    0.000 frame.py:8567(func)
#         1    0.000    0.000    0.000    0.000 frame.py:8879(_get_agg_axis)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1701(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1705(ravel)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2333(_all_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2337(all)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2876(_prod_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2881(prod)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:52(_wrapfunc)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:70(_wrapreduction)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:995(_argsort_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:999(argsort)
#         5    0.000    0.000    0.000    0.000 function.py:48(__call__)
#         2    0.000    0.000    0.000    0.000 function_base.py:4612(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:4616(append)
#      1138    0.000    0.000    0.001    0.000 generic.py:10(_check)
#         2    0.000    0.000    0.001    0.001 generic.py:11389(stat_func)
#         1    0.000    0.000    0.001    0.001 generic.py:11556(logical_func)
#         1    0.000    0.000    0.000    0.000 generic.py:1319(__invert__)
#         2    0.000    0.000    0.000    0.000 generic.py:1667(__hash__)
#         1    0.000    0.000    0.000    0.000 generic.py:1673(__iter__)
#        27    0.000    0.000    0.000    0.000 generic.py:195(__init__)
#        10    0.000    0.000    0.000    0.000 generic.py:232(attrs)
#         3    0.000    0.000    0.000    0.000 generic.py:249(_validate_dtype)
#         9    0.000    0.000    0.000    0.000 generic.py:294(_data)
#        12    0.000    0.000    0.000    0.000 generic.py:3180(_set_as_cached)
#         2    0.000    0.000    0.000    0.000 generic.py:3250(_clear_item_cache)
#         2    0.000    0.000    0.001    0.001 generic.py:3256(take)
#         1    0.000    0.000    0.000    0.000 generic.py:334(_construct_axes_from_arguments)
#         2    0.000    0.000    0.001    0.001 generic.py:3355(_take_with_is_copy)
#         5    0.000    0.000    0.000    0.000 generic.py:3532(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 generic.py:3551(_slice)
#         1    0.000    0.000    0.001    0.001 generic.py:3572(_set_item)
#         3    0.000    0.000    0.000    0.000 generic.py:3582(_set_is_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:3609(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:362(<dictcomp>)
#        38    0.000    0.000    0.000    0.000 generic.py:365(_get_axis_number)
#        31    0.000    0.000    0.000    0.000 generic.py:377(_get_axis)
#         3    0.000    0.000    0.000    0.000 generic.py:382(_get_block_manager_axis)
#         1    0.000    0.000    0.001    0.001 generic.py:4214(reindex)
#         2    0.000    0.000    0.000    0.000 generic.py:4447(<genexpr>)
#         4    0.000    0.000    0.000    0.000 generic.py:447(_info_axis)
#         1    0.000    0.000    0.001    0.001 generic.py:4642(head)
#         8    0.000    0.000    0.000    0.000 generic.py:471(ndim)
#         1    0.000    0.000    0.000    0.000 generic.py:494(size)
#        10    0.000    0.000    0.000    0.000 generic.py:5095(__finalize__)
#        25    0.000    0.000    0.000    0.000 generic.py:5123(__getattr__)
#        47    0.000    0.000    0.000    0.000 generic.py:5141(__setattr__)
#         6    0.000    0.000    0.001    0.000 generic.py:5197(_protect_consolidate)
#         4    0.000    0.000    0.001    0.000 generic.py:5208(_consolidate_inplace)
#         4    0.000    0.000    0.001    0.000 generic.py:5211(f)
#         2    0.000    0.000    0.000    0.000 generic.py:5238(_is_mixed_type)
#         2    0.000    0.000    0.000    0.000 generic.py:5240(<lambda>)
#         1    0.000    0.000    0.000    0.000 generic.py:5268(values)
#         1    0.000    0.000    0.000    0.000 generic.py:5350(dtypes)
#         1    0.000    0.000    0.001    0.001 generic.py:5393(astype)
#         1    0.000    0.000    0.000    0.000 generic.py:7060(isna)
#         2    0.000    0.000    0.000    0.000 idna.py:147(encode)
#         1    0.000    0.000    0.000    0.000 index_tricks.py:316(__getitem__)
#         2    0.000    0.000    0.000    0.000 indexers.py:210(maybe_convert_indices)
#         2    0.000    0.000    0.000    0.000 indexers.py:348(check_array_indexer)
#        16    0.000    0.000    0.000    0.000 indexers.py:52(is_list_like_indexer)
#         9    0.000    0.000    0.000    0.000 indexing.py:100(iloc)
#        16    0.000    0.000    0.000    0.000 indexing.py:1334(_validate_key)
#         8    0.000    0.000    0.000    0.000 indexing.py:1400(_is_scalar_access)
#        16    0.000    0.000    0.000    0.000 indexing.py:1419(_validate_integer)
#         8    0.000    0.000    0.001    0.000 indexing.py:1441(_getitem_tuple)
#         9    0.000    0.000    0.001    0.000 indexing.py:1474(_getitem_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:1500(_get_slice_axis)
#         3    0.000    0.000    0.000    0.000 indexing.py:2128(convert_to_index_sliceable)
#         2    0.000    0.000    0.000    0.000 indexing.py:2153(check_bool_indexer)
#        16    0.000    0.000    0.000    0.000 indexing.py:2260(is_label_like)
#         1    0.000    0.000    0.000    0.000 indexing.py:2270(need_slice)
#         8    0.000    0.000    0.000    0.000 indexing.py:694(_has_valid_tuple)
#         8    0.000    0.000    0.000    0.000 indexing.py:709(_is_nested_tuple_indexer)
#        24    0.000    0.000    0.000    0.000 indexing.py:715(<genexpr>)
#         8    0.000    0.000    0.001    0.000 indexing.py:757(_getitem_lowerdim)
#         9    0.000    0.000    0.002    0.000 indexing.py:864(__getitem__)
#        24    0.000    0.000    0.000    0.000 indexing.py:866(<genexpr>)
#        28    0.000    0.000    0.000    0.000 inference.py:185(is_array_like)
#         4    0.000    0.000    0.000    0.000 inference.py:263(is_dict_like)
#        12    0.000    0.000    0.000    0.000 inference.py:289(<genexpr>)
#        61    0.000    0.000    0.000    0.000 inference.py:322(is_hashable)
#        42    0.000    0.000    0.000    0.000 inference.py:360(is_sequence)
#         1    0.000    0.000    0.000    0.000 inference.py:96(is_file_like)
#         1    0.000    0.000    0.000    0.000 inspect.py:72(isclass)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:705(get_ipython)
#         7    0.000    0.000    0.001    0.000 iostream.py:197(schedule)
#         6    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         6    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#         6    0.000    0.000    0.001    0.000 iostream.py:386(write)
#         7    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         1    0.000    0.000    0.001    0.001 managers.py:1162(insert)
#         2    0.000    0.000    0.000    0.000 managers.py:1238(reindex_indexer)
#         2    0.000    0.000    0.000    0.000 managers.py:1284(<listcomp>)
#         7    0.000    0.000    0.000    0.000 managers.py:132(__init__)
#         7    0.000    0.000    0.000    0.000 managers.py:138(<listcomp>)
#         2    0.000    0.000    0.001    0.000 managers.py:1427(take)
#        20    0.000    0.000    0.000    0.000 managers.py:1532(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1553(from_blocks)
#         4    0.000    0.000    0.000    0.000 managers.py:156(from_blocks)
#         7    0.000    0.000    0.001    0.000 managers.py:1564(from_array)
#        42    0.000    0.000    0.000    0.000 managers.py:1575(_block)
#        17    0.000    0.000    0.000    0.000 managers.py:1602(dtype)
#        19    0.000    0.000    0.000    0.000 managers.py:1613(internal_values)
#         1    0.000    0.000    0.000    0.000 managers.py:1621(is_consolidated)
#        22    0.000    0.000    0.000    0.000 managers.py:163(blknos)
#         1    0.000    0.000    0.001    0.001 managers.py:1675(create_block_manager_from_arrays)
#         3    0.000    0.000    0.000    0.000 managers.py:1680(<genexpr>)
#         1    0.000    0.000    0.001    0.001 managers.py:1715(form_blocks)
#        21    0.000    0.000    0.000    0.000 managers.py:179(blklocs)
#         1    0.000    0.000    0.000    0.000 managers.py:1812(_simple_blockify)
#         1    0.000    0.000    0.000    0.000 managers.py:1827(_multi_blockify)
#         3    0.000    0.000    0.000    0.000 managers.py:1830(<lambda>)
#         2    0.000    0.000    0.000    0.000 managers.py:1843(_stack_arrays)
#         8    0.000    0.000    0.000    0.000 managers.py:1846(_asarray_compat)
#         2    0.000    0.000    0.000    0.000 managers.py:1852(_shape_compat)
#         2    0.000    0.000    0.001    0.000 managers.py:1889(_consolidate)
#        10    0.000    0.000    0.000    0.000 managers.py:1894(<lambda>)
#         3    0.000    0.000    0.001    0.000 managers.py:1906(_merge_blocks)
#         2    0.000    0.000    0.000    0.000 managers.py:1921(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:1922(<listcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:2008(_fast_count_smallints)
#        16    0.000    0.000    0.000    0.000 managers.py:212(shape)
#        48    0.000    0.000    0.000    0.000 managers.py:214(<genexpr>)
#        27    0.000    0.000    0.000    0.000 managers.py:216(ndim)
#         1    0.000    0.000    0.000    0.000 managers.py:233(_is_single_block)
#         6    0.000    0.000    0.000    0.000 managers.py:238(_rebuild_blknos_and_blklocs)
#         8    0.000    0.000    0.000    0.000 managers.py:259(items)
#         1    0.000    0.000    0.000    0.000 managers.py:263(get_dtypes)
#         1    0.000    0.000    0.000    0.000 managers.py:264(<listcomp>)
#         4    0.000    0.000    0.000    0.000 managers.py:306(__len__)
#         2    0.000    0.000    0.000    0.000 managers.py:321(_verify_integrity)
#         7    0.000    0.000    0.000    0.000 managers.py:323(<genexpr>)
#         3    0.000    0.000    0.000    0.000 managers.py:366(apply)
#         3    0.000    0.000    0.000    0.000 managers.py:385(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:511(isna)
#         1    0.000    0.000    0.000    0.000 managers.py:592(astype)
#        11    0.000    0.000    0.000    0.000 managers.py:675(is_consolidated)
#         5    0.000    0.000    0.000    0.000 managers.py:683(_consolidate_check)
#         5    0.000    0.000    0.000    0.000 managers.py:684(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:688(is_mixed_type)
#         2    0.000    0.000    0.000    0.000 managers.py:698(any_extension_types)
#         5    0.000    0.000    0.000    0.000 managers.py:701(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:757(get_slice)
#         1    0.000    0.000    0.000    0.000 managers.py:763(<listcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:806(as_array)
#         4    0.000    0.000    0.000    0.000 managers.py:961(consolidate)
#         8    0.000    0.000    0.001    0.000 managers.py:977(_consolidate_inplace)
#        12    0.000    0.000    0.000    0.000 managers.py:984(iget)
#         8    0.000    0.000    0.000    0.000 managers.py:999(iget_values)
#         2    0.000    0.000    0.000    0.000 message.py:120(__init__)
#         4    0.000    0.000    0.000    0.000 message.py:29(_splitparam)
#         1    0.000    0.000    0.000    0.000 message.py:303(set_payload)
#         9    0.000    0.000    0.000    0.000 message.py:462(get)
#        10    0.000    0.000    0.000    0.000 message.py:479(set_raw)
#         4    0.000    0.000    0.000    0.000 message.py:564(get_content_type)
#         3    0.000    0.000    0.000    0.000 message.py:588(get_content_maintype)
#     40/38    0.000    0.000    0.001    0.000 missing.py:130(_isna)
#         1    0.000    0.000    0.000    0.000 missing.py:136(dispatch_fill_zeros)
#        10    0.000    0.000    0.001    0.000 missing.py:193(_isna_ndarraylike)
#         9    0.000    0.000    0.000    0.000 missing.py:235(_isna_string_dtype)
#         6    0.000    0.000    0.001    0.000 missing.py:255(notna)
#         4    0.000    0.000    0.000    0.000 missing.py:358(array_equivalent)
#         2    0.000    0.000    0.000    0.000 missing.py:456(_array_equivalent_object)
#     40/38    0.000    0.000    0.001    0.000 missing.py:47(isna)
#         1    0.000    0.000    0.000    0.000 missing.py:665(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 missing.py:75(clean_fill_method)
#         7    0.000    0.000    0.000    0.000 multiarray.py:1043(copyto)
#        16    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:852(bincount)
#         2    0.000    0.000    0.000    0.000 nanops.py:1258(_maybe_null_out)
#         2    0.000    0.000    0.000    0.000 nanops.py:1290(check_below_min_count)
#         3    0.000    0.000    0.000    0.000 nanops.py:168(_get_fill_value)
#         3    0.000    0.000    0.000    0.000 nanops.py:193(_maybe_get_mask)
#         3    0.000    0.000    0.000    0.000 nanops.py:237(_get_values)
#         3    0.000    0.000    0.000    0.000 nanops.py:322(_na_ok_dtype)
#         2    0.000    0.000    0.000    0.000 nanops.py:328(_wrap_results)
#         1    0.000    0.000    0.000    0.000 nanops.py:396(nanany)
#         2    0.000    0.000    0.000    0.000 nanops.py:470(nansum)
#         7    0.000    0.000    0.000    0.000 nanops.py:57(check)
#         2    0.000    0.000    0.000    0.000 nanops.py:61(_f)
#         9    0.000    0.000    0.000    0.000 nanops.py:64(<genexpr>)
#        15    0.000    0.000    0.000    0.000 numeric.py:150(is_all_dates)
#         7    0.000    0.000    0.000    0.000 numeric.py:268(full)
#         1    0.000    0.000    0.000    0.000 numeric.py:81(_validate_dtype)
#        28    0.000    0.000    0.000    0.000 numerictypes.py:286(issubclass_)
#        14    0.000    0.000    0.000    0.000 numerictypes.py:360(issubdtype)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:545(_can_coerce_all)
#         8    0.000    0.000    0.000    0.000 numerictypes.py:554(<listcomp>)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:569(find_common_type)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:621(<listcomp>)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:622(<listcomp>)
#         6    0.000    0.000    0.000    0.000 numpy_.py:162(__init__)
#         2    0.000    0.000    0.000    0.000 numpy_.py:210(__array__)
#         4    0.000    0.000    0.000    0.000 numpy_.py:414(to_numpy)
#         6    0.000    0.000    0.000    0.000 numpy_.py:50(__init__)
#         3    0.000    0.000    0.000    0.000 os.py:670(__getitem__)
#         3    0.000    0.000    0.000    0.000 os.py:748(encode)
#         1    0.000    0.000    0.000    0.000 parse.py:1002(_splittype)
#         1    0.000    0.000    0.000    0.000 parse.py:1023(_splithost)
#         4    0.000    0.000    0.000    0.000 parse.py:110(_coerce_args)
#         1    0.000    0.000    0.000    0.000 parse.py:1133(_splittag)
#         2    0.000    0.000    0.000    0.000 parse.py:366(urlparse)
#         2    0.000    0.000    0.000    0.000 parse.py:417(urlsplit)
#         1    0.000    0.000    0.000    0.000 parse.py:624(unquote)
#         1    0.000    0.000    0.000    0.000 parse.py:981(unwrap)
#         4    0.000    0.000    0.000    0.000 parse.py:99(_noop)
#         1    0.000    0.000    0.000    0.000 parser.py:17(__init__)
#         1    0.000    0.000    0.001    0.001 parser.py:41(parse)
#         1    0.000    0.000    0.001    0.001 parser.py:59(parsestr)
#         1    0.000    0.000    0.000    0.000 parsers.py:1005(_clean_options)
#         1    0.000    0.000    0.001    0.001 parsers.py:1176(_make_engine)
#         1    0.000    0.000    0.010    0.010 parsers.py:1194(read)
#         1    0.000    0.000    0.000    0.000 parsers.py:1219(_create_index)
#         3    0.000    0.000    0.000    0.000 parsers.py:1233(_is_index_col)
#         3    0.000    0.000    0.000    0.000 parsers.py:1237(_is_potential_multi_index)
#         6    0.000    0.000    0.000    0.000 parsers.py:1261(<genexpr>)
#         1    0.000    0.000    0.000    0.000 parsers.py:1339(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 parsers.py:1389(_validate_parse_dates_arg)
#         1    0.000    0.000    0.000    0.000 parsers.py:1412(__init__)
#         1    0.000    0.000    0.000    0.000 parsers.py:1499(_validate_parse_dates_presence)
#         1    0.000    0.000    0.000    0.000 parsers.py:1535(<setcomp>)
#         1    0.000    0.000    0.000    0.000 parsers.py:1551(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 parsers.py:1637(_maybe_dedup_names)
#         2    0.000    0.000    0.000    0.000 parsers.py:1665(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 parsers.py:1671(_make_index)
#         1    0.000    0.000    0.000    0.000 parsers.py:1959(_do_date_conversions)
#         1    0.000    0.000    0.001    0.001 parsers.py:1981(__init__)
#         1    0.000    0.000    0.000    0.000 parsers.py:2087(close)
#         1    0.000    0.000    0.000    0.000 parsers.py:2097(_set_noconvert_columns)
#         1    0.000    0.000    0.002    0.002 parsers.py:2153(read)
#         1    0.000    0.000    0.000    0.000 parsers.py:2226(<listcomp>)
#         1    0.000    0.000    0.000    0.000 parsers.py:2228(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 parsers.py:3335(_make_date_converter)
#         1    0.000    0.000    0.000    0.000 parsers.py:3380(_process_date_conversion)
#         1    0.000    0.000    0.000    0.000 parsers.py:3468(_clean_na_values)
#         2    0.000    0.000    0.000    0.000 parsers.py:369(_validate_integer)
#         1    0.000    0.000    0.000    0.000 parsers.py:398(_validate_names)
#         1    0.000    0.000    0.207    0.207 parsers.py:420(_read)
#         1    0.000    0.000    0.207    0.207 parsers.py:533(read_csv)
#         1    0.000    0.000    0.001    0.001 parsers.py:856(__init__)
#         1    0.000    0.000    0.000    0.000 parsers.py:948(close)
#         1    0.000    0.000    0.000    0.000 parsers.py:951(_get_options_with_defaults)
#         1    0.000    0.000    0.000    0.000 parsers.py:989(_check_file_or_buffer)
#         2    0.000    0.000    0.000    0.000 posixpath.py:228(expanduser)
#        42    0.000    0.000    0.001    0.000 printing.py:166(pprint_thing)
#        42    0.000    0.000    0.000    0.000 printing.py:197(as_escaped_string)
#         4    0.000    0.000    0.000    0.000 printing.py:29(adjoin)
#         4    0.000    0.000    0.000    0.000 printing.py:50(<listcomp>)
#        41    0.000    0.000    0.000    0.000 printing.py:64(justify)
#        16    0.000    0.000    0.000    0.000 printing.py:69(<listcomp>)
#        25    0.000    0.000    0.000    0.000 printing.py:73(<listcomp>)
#         2    0.000    0.000    0.000    0.000 range.py:134(_simple_new)
#         4    0.000    0.000    0.000    0.000 range.py:153(_data)
#         1    0.000    0.000    0.000    0.000 range.py:198(_format_with_header)
#         1    0.000    0.000    0.000    0.000 range.py:205(<listcomp>)
#         1    0.000    0.000    0.000    0.000 range.py:214(start)
#         1    0.000    0.000    0.000    0.000 range.py:237(stop)
#         1    0.000    0.000    0.000    0.000 range.py:260(step)
#         2    0.000    0.000    0.000    0.000 range.py:320(dtype)
#         2    0.000    0.000    0.000    0.000 range.py:393(_shallow_copy)
#         6    0.000    0.000    0.000    0.000 range.py:452(equals)
#        40    0.000    0.000    0.000    0.000 range.py:687(__len__)
#         1    0.000    0.000    0.000    0.000 range.py:697(__getitem__)
#         1    0.000    0.000    0.001    0.001 range.py:86(__new__)
#         1    0.000    0.000    0.000    0.000 request.py:1271(do_request_)
#         1    0.000    0.000    0.189    0.189 request.py:1309(do_open)
#         1    0.000    0.000    0.000    0.000 request.py:1323(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 request.py:1336(<dictcomp>)
# ...
#         1    0.000    0.000    0.000    0.000 socket.py:301(makefile)
#         7    0.001    0.000    0.001    0.000 socket.py:357(send)
#         1    0.000    0.000    0.000    0.000 socket.py:486(_decref_socketios)
#         1    0.000    0.000    0.000    0.000 socket.py:492(_real_close)
#         2    0.000    0.000    0.000    0.000 socket.py:496(close)
#         1    0.000    0.000    0.000    0.000 socket.py:502(detach)
#         1    0.000    0.000    0.000    0.000 socket.py:512(family)
#         1    0.000    0.000    0.000    0.000 socket.py:518(type)
#         1    0.000    0.000    0.000    0.000 socket.py:643(__init__)
#         2    0.000    0.000    0.064    0.032 socket.py:655(readinto)
#         3    0.000    0.000    0.000    0.000 socket.py:694(readable)
#         1    0.004    0.004    0.004    0.004 socket.py:732(close)
#         1    0.000    0.000    0.047    0.047 socket.py:771(create_connection)
#         1    0.000    0.000    0.013    0.013 socket.py:901(getaddrinfo)
#         4    0.000    0.000    0.000    0.000 socket.py:97(_intenum_converter)
#         6    0.000    0.000    0.000    0.000 ssl.py:1078(_checkClosed)
#         1    0.000    0.000    0.000    0.000 ssl.py:1082(_check_connected)
#         2    0.000    0.000    0.064    0.032 ssl.py:1090(read)
#         1    0.000    0.000    0.000    0.000 ssl.py:1166(send)
#         1    0.000    0.000    0.000    0.000 ssl.py:1193(sendall)
#         2    0.000    0.000    0.064    0.032 ssl.py:1230(recv_into)
#         1    0.000    0.000    0.000    0.000 ssl.py:1298(_real_close)
#         1    0.000    0.000    0.057    0.057 ssl.py:1302(do_handshake)
#         1    0.000    0.000    0.000    0.000 ssl.py:482(__new__)
#         1    0.000    0.000    0.000    0.000 ssl.py:486(_encode_hostname)
#         1    0.000    0.000    0.058    0.058 ssl.py:494(wrap_socket)
#         1    0.000    0.000    0.016    0.016 ssl.py:569(load_default_certs)
#         2    0.000    0.000    0.000    0.000 ssl.py:710(verify_mode)
#         1    0.000    0.000    0.000    0.000 ssl.py:718(verify_mode)
#         1    0.000    0.000    0.016    0.016 ssl.py:723(create_default_context)
#         1    0.000    0.000    0.057    0.057 ssl.py:983(_create)
#         7    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         7    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         7    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#        42    0.000    0.000    0.000    0.000 typing.py:255(inner)
#        84    0.000    0.000    0.000    0.000 typing.py:329(__hash__)
#    126/42    0.000    0.000    0.000    0.000 typing.py:720(__hash__)
#         6    0.000    0.000    0.000    0.000 utils.py:51(_has_surrogates)
#         2    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         2    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#        15    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10e444808}
#        82    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         1    0.012    0.012    0.012    0.012 {built-in method _socket.getaddrinfo}
#         4    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#     16/15    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        31    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.223    0.223 {built-in method builtins.exec}
#      1674    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       179    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#   295/253    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      2931    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#       743    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 1177/1060    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        71    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         3    0.000    0.000    0.008    0.003 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        13    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#   110/105    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#     44/36    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        39    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        40    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        29    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         9    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.get_terminal_size}
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         1    0.000    0.000    0.000    0.000 {function HTTPResponse.flush at 0x7ff847e329d0}
#         2    0.000    0.000    0.000    0.000 {function SocketIO.close at 0x7ff84735b160}
#         1    0.000    0.000    0.000    0.000 {function socket.close at 0x7ff847359790}
#         1    0.000    0.000    0.000    0.000 {function socket.detach at 0x7ff847359820}
#         2    0.000    0.000    0.000    0.000 {method '_checkClosed' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {method '_checkReadable' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 {method '_wrap_socket' of '_ssl._SSLContext' objects}
#         7    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        22    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       156    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'capitalize' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.004    0.004 {method 'close' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#         1    0.034    0.034    0.034    0.034 {method 'connect' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.057    0.057    0.057    0.057 {method 'do_handshake' of '_ssl._SSLSocket' objects}
#     22/21    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#        18    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_socket.socket' objects}
#        12    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        39    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'fullmatch' of 're.Pattern' objects}
#       115    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getpeername' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getsockopt' of '_socket.socket' objects}
#         3    0.000    0.000    0.000    0.000 {method 'gettimeout' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#         3    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        19    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#        43    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        96    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#       102    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         9    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        17    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         2    0.064    0.032    0.064    0.032 {method 'read' of '_ssl._SSLSocket' objects}
#         1    0.001    0.001    0.002    0.002 {method 'read' of 'pandas._libs.parsers.TextReader' objects}
#        12    0.000    0.000    0.064    0.005 {method 'readline' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        40    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       123    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        96    0.000    0.000    0.000    0.000 {method 'rjust' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'seek' of '_io.StringIO' objects}
#         1    0.016    0.016    0.016    0.016 {method 'set_default_verify_paths' of '_ssl._SSLContext' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setsockopt' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'settimeout' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#       114    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'title' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'truncate' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_ssl._SSLSocket' objects}
#         1    0.000    0.000    0.000    0.000 {method 'writelines' of '_io._IOBase' objects}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#        11    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#        11    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        61    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        43    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         7    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        80    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#       137    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.map_infer}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.ops.scalar_compare}

# %%
"""Sorting a large, randomly generated string and writing it to disk"""
# Source: https://toucantoco.com/en/tech-blog/tech/python-performance-optimization
# Slightly modified for class-use
import random


def write_sorted_letters(nb_letters=2 * 10**6):
    random_string = ''
    for i in range(nb_letters):
        random_string += random.choice('abcdefghijklmnopqrstuvwxyz')
    sorted_string = sorted(random_string)

    with open("sorted_text.txt", "w") as sorted_text:
        for character in sorted_string:
            sorted_text.write(character)

# %% [markdown]
# ### Profile it

# %%
cProfile.run("write_sorted_letters()")
# Out:
#          12460935 function calls in 3.791 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    1.045    1.045    3.783    3.783 <ipython-input-48-6c33e28a9206>:7(write_sorted_letters)
#         1    0.008    0.008    3.791    3.791 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#   2000000    0.894    0.000    1.292    0.000 random.py:250(_randbelow_with_getrandbits)
#   2000000    0.840    0.000    2.306    0.000 random.py:285(choice)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         1    0.000    0.000    3.791    3.791 {built-in method builtins.exec}
#   2000000    0.174    0.000    0.174    0.000 {built-in method builtins.len}
#         1    0.255    0.255    0.255    0.255 {built-in method builtins.sorted}
#         1    0.002    0.002    0.002    0.002 {built-in method io.open}
#   2000000    0.159    0.000    0.159    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#   2460926    0.239    0.000    0.239    0.000 {method 'getrandbits' of '_random.Random' objects}
#   2000000    0.175    0.000    0.175    0.000 {method 'write' of '_io.TextIOWrapper' objects}

# %% [markdown]
# ## Let's install `line_profiler`
# https://github.com/pyutils/line_profiler

# %%
# !pip install line_profiler
# Out:
# Collecting line_profiler
#   Downloading line_profiler-3.1.0.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 3.1 MB/s eta 0:00:011
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: IPython in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from line_profiler) (7.19.0)
# Requirement already satisfied: backcall in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (0.2.0)
# Requirement already satisfied: decorator in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (0.17.1)
# Requirement already satisfied: pickleshare in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (3.0.8)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (0.1.0)
# Requirement already satisfied: pygments in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (2.7.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (50.3.1.post20201107)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from IPython->line_profiler) (5.0.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->IPython->line_profiler) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->line_profiler) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython->line_profiler) (0.6.0)
# Requirement already satisfied: ipython-genutils in /Users/suneelchakravorty/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.2->IPython->line_profiler) (0.2.0)
# Building wheels for collected packages: line-profiler
#   Building wheel for line-profiler (PEP 517) ... done
#   Created wheel for line-profiler: filename=line_profiler-3.1.0-cp38-cp38-macosx_10_16_x86_64.whl size=52714 sha256=34806573d32897f80e7f8f707ba24d9c9e232241ff3ef38beefcbc4141010074
#   Stored in directory: /Users/suneelchakravorty/Library/Caches/pip/wheels/8c/77/e9/c5e6acd4b2f433b82d0328e06eeef6d8c06a27db842d3cfb53
# Successfully built line-profiler
# Installing collected packages: line-profiler
# Successfully installed line-profiler-3.1.0

# %%
# %load_ext line_profiler

# %%
# %lprun -f write_sorted_letters write_sorted_letters()

# %% [markdown]
# Where is the first bottleneck?

# %% [markdown]
# Where is the second bottleneck?
